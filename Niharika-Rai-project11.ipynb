# %% [markdown]
# # Project 11 -- [Niharika] [Rai]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
class Flight:
    def __init__(self, flight_number, origin_airport_ID, destination_airport_ID, departure_time, arrival_time, departure_delay, arrival_delay): 
        self.flight_number = flight_number 
        self.origin_airport_ID = origin_airport_ID
        self.destination_airport_ID = destination_airport_ID
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.departure_delay = departure_delay
        self.arrival_delay = arrival_delay 
    
    def get_arrdelay(self): 
        return self.arrival_delay

# %% [markdown]
# For parts a and b, I watched the "hint for Question 1 on TDM 10200 Project 11" video and constructed my code. This is because Python classes is a new concept and I needed guidance to underderstand how the codes work in classes. The video is linked here: https://the-examples-book.com/programming-languages/python/hints-for-TDM-10200-project-11.

# %% [markdown]
# ## Question 2

# %%
import pandas as pd
columns_to_read = [
    'DepDelay', 'ArrDelay', 'Flight_Number_Reporting_Airline', 'Distance',
    'CarrierDelay', 'WeatherDelay',
    'DepTime', 'ArrTime', 'Origin',
    'Dest', 'AirTime'
]

col_types = {
    'Flight_Number_Reporting_Airline': 'int64', 
    'Origin': 'object', 
    'Dest': 'object', 
    'DepTime': 'float64',
    'ArrTime': 'float64',
    'DepDelay': 'float64',
    'ArrDelay': 'float64',
    'Distance': 'float64',
    'CarrierDelay': 'float64',
    'WeatherDelay': 'float64',
}

myDF = pd.read_csv("/anvil/projects/tdm/data/flights/2014.csv", usecols=columns_to_read, dtype=col_types, nrows=100)

# %%
myDF.head()
# Out:
#    Flight_Number_Reporting_Airline Origin Dest  DepTime  DepDelay  ArrTime  \
# 0                             2377    DFW  ICT    935.0      -5.0   1051.0
# 1                             2377    DFW  ICT    951.0      11.0   1115.0
# 2                             2377    ICT  DFW   1144.0       9.0   1302.0
# 3                             2377    ICT  DFW   1134.0      -1.0   1253.0
# 4                             2377    ICT  DFW   1129.0      -6.0   1244.0
#
#    ArrDelay  AirTime  Distance  CarrierDelay  WeatherDelay
# 0      -4.0     56.0     328.0           NaN           NaN
# 1      20.0     54.0     328.0          11.0           0.0
# 2       2.0     57.0     328.0           NaN           NaN
# 3      -7.0     53.0     328.0           NaN           NaN
# 4     -16.0     52.0     328.0           NaN           NaN

# %%
longlistofflights = [] 
for index, row in myDF.iterrows(): 
    myflight = Flight(
        flight_number = row['Flight_Number_Reporting_Airline'],
        origin_airport_ID = row['Origin'],
        destination_airport_ID = row['Dest'],
        departure_time = row['DepTime'],
        arrival_time = row['ArrTime'],
        departure_delay = row['DepDelay'], 
        arrival_delay = row['ArrDelay']
    
    )
    longlistofflights.append(myflight)

# %%
len(longlistofflights)
# Out:
# 100

# %% [markdown]
# For parts a and b, I watched the "hint for Question 2 on TDM 10200 Project 11" and "more hints for Question 2 on TDM 10200 Project 11" videos to construct my code. To check if my code was correct, I used the len function on the longlistofflights which gave me an output of 100. This means that I met the question's criteria in part b. The video is linked here: https://the-examples-book.com/programming-languages/python/hints-for-TDM-10200-project-11.

# %% [markdown]
# ## Question 3

# %%
delays_dest = {} 
for myflight in longlistofflights: 
    if myflight.destination_airport_ID not in delays_dest:
        delays_dest[myflight.destination_airport_ID] = [] 
    delays_dest[myflight.destination_airport_ID].append(myflight.get_arrdelay())

# %%
delays_dest
# Out:
# {'ICT': [-4.0, 20.0],
#  'DFW': [2.0,
#   -7.0,
#   -16.0,
#   1.0,
#   9.0,
#   30.0,
#   27.0,
#   8.0,
#   91.0,
#   -3.0,
#   -13.0,
#   21.0,
#   -2.0,
#   -6.0,
#   -16.0,
#   37.0,
#   19.0,
#   -17.0,
#   -11.0,
#   5.0,
#   34.0,
#   -2.0,
#   -3.0,
#   -2.0,
#   -26.0,
#   -17.0,
#   -14.0,
#   -7.0,
#   15.0,
#   -19.0,
#   25.0],
#  'TPA': [-10.0,
#   57.0,
#   -1.0,
#   53.0,
#   83.0,
#   34.0,
#   -15.0,
#   12.0,
#   16.0,
#   -11.0,
#   2.0,
#   -11.0,
#   -4.0,
#   -7.0,
#   -14.0,
#   -10.0,
#   34.0,
#   -10.0,
#   -5.0,
#   -13.0],
#  'OGG': [-65.0, -52.0, -18.0, -17.0, -44.0, -42.0, -39.0, 0.0],
#  'SJC': [-12.0, -16.0, -3.0],
#  'KOA': [-34.0, -42.0, -46.0, -36.0],
#  'SMF': [-8.0],
#  'SEA': [-16.0, 4.0, 4.0, -3.0, -38.0, -20.0, -19.0, -15.0, -30.0],
#  'PDX': [-32.0, -21.0, -22.0],
#  'OAK': [-14.0, -21.0],
#  'HNL': [-52.0, -23.0, -36.0, -29.0, -36.0, -8.0, -17.0],
#  'SAN': [8.0, -21.0, -23.0],
#  'ANC': [-27.0, -27.0],
#  'LIH': [-58.0, -24.0],
# ...

# %%
average_delays ={myairport: sum(mydelays)/len(mydelays) for myairport, mydelays in delays_dest.items()}

# %%
average_delays
# Out:
# {'ICT': 8.0,
#  'DFW': 4.612903225806452,
#  'TPA': 9.0,
#  'OGG': -34.625,
#  'SJC': -10.333333333333334,
#  'KOA': -39.5,
#  'SMF': -8.0,
#  'SEA': -14.777777777777779,
#  'PDX': -25.0,
#  'OAK': -17.5,
#  'HNL': -28.714285714285715,
#  'SAN': -12.0,
#  'ANC': -27.0,
#  'LIH': -41.0,
#  'BLI': -18.0,
#  'DCA': -22.0}

# %% [markdown]
# For parts a and b, I watched the "hint for Question 3 on TDM 10200 Project 11" video to construct my code. Initially, I struggled to understand why the code was written the way it was in part a. But later, I realized that this was because mydelays was going to be used in the average delay calculation. Also, in part b, the average delay calculation makes sense but it is a different way to calculate the average as I am more used to directly using the .mean() function. And lastly, the video is linked here: https://the-examples-book.com/programming-languages/python/hints-for-TDM-10200-project-11.

# %% [markdown]
# ## Question 4

# %%
def arr_avg_delays(myflightlist):
    """
    The function is called the arr_avg_delays. 
    This is because the function's purpose is to take in the myflightlist as an input variable and output the average arrival delays accoring to the destination. 
    The input variable is myflightlist which contains the data for flight destination airports and their delay times. 
    The output/return variable is the average_delays because it calculates the average value using all the delay times for the listed flight destination airports. 
    The output variable also presents the information in a dictionary. 
    """ 
    delays_dest = {}
    for myflight in myflightlist: 
        if myflight.destination_airport_ID not in delays_dest:
            delays_dest[myflight.destination_airport_ID] = [] 
        delays_dest[myflight.destination_airport_ID].append(myflight.get_arrdelay())
    average_delays ={myairport: sum(mydelays)/len(mydelays) for myairport, mydelays in delays_dest.items()} 
    return average_delays

# %%
arr_avg_delays(longlistofflights)
# Out:
# {'ICT': 8.0,
#  'DFW': 4.612903225806452,
#  'TPA': 9.0,
#  'OGG': -34.625,
#  'SJC': -10.333333333333334,
#  'KOA': -39.5,
#  'SMF': -8.0,
#  'SEA': -14.777777777777779,
#  'PDX': -25.0,
#  'OAK': -17.5,
#  'HNL': -28.714285714285715,
#  'SAN': -12.0,
#  'ANC': -27.0,
#  'LIH': -41.0,
#  'BLI': -18.0,
#  'DCA': -22.0}

# %% [markdown]
# For parts a and b, I watched the "hint for Question 4 on TDM 10200 Project 11" video to construct my code. I did not really have to include any extra codes because I just had to combine my work from question 3 to create this function. The only difference was that in the loop statement, I replaced the longlistofflights (from question 2) with myflightlist(current input variable). I later used the longlistofflights as an input, for part b, and found that it resulted in the same output as in question 3. The video is linked here: https://the-examples-book.com/programming-languages/python/hints-for-TDM-10200-project-11.

# %% [markdown]
# ## Question 5

# %%
class Flight:
    def __init__(self, flight_number, origin_airport_ID, destination_airport_ID, departure_time, arrival_time, departure_delay, arrival_delay): 
        self.flight_number = flight_number 
        self.origin_airport_ID = origin_airport_ID
        self.destination_airport_ID = destination_airport_ID
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.departure_delay = departure_delay
        self.arrival_delay = arrival_delay 
    
    def get_arrdelay(self): 
        return self.arrival_delay 
    
    def get_depdelay(self): 
        return self.departure_delay

# %%
longlistofflights = [] 
for index, row in myDF.iterrows(): 
    myflight = Flight(
        flight_number = row['Flight_Number_Reporting_Airline'],
        origin_airport_ID = row['Origin'],
        destination_airport_ID = row['Dest'],
        departure_time = row['DepTime'],
        arrival_time = row['ArrTime'],
        departure_delay = row['DepDelay'], 
        arrival_delay = row['ArrDelay']
    
    )
    longlistofflights.append(myflight)

# %%
def dep_avg_delays(myflightlist): 
    """
    The function is called the dep_avg_delays. 
    This is because the function's purpose is to take in the myflightlist as an input variable and output the average departure delays accoring to the origin. 
    The input variable is myflightlist which contains the data for flight origin airport and their delay times. 
    The output/return variable is the average_delays because it calculates the average value using all the delay times for the listed flight origin airport. 
    The output variable also presents the information in a dictionary. 
    """ 
    delays_origin = {}
    for myflight in myflightlist: 
        if myflight.origin_airport_ID not in delays_origin:
            delays_origin[myflight.origin_airport_ID] = [] 
        delays_origin[myflight.origin_airport_ID].append(myflight.get_depdelay())
    average_delays ={myairport: sum(mydelays)/len(mydelays) for myairport, mydelays in delays_origin.items()} 
    return average_delays

# %%
dep_avg_delays(longlistofflights)
# Out:
# {'DFW': 3.0,
#  'ICT': 10.612903225806452,
#  'MIA': 15.05,
#  'BLI': -10.5,
#  'PDX': -9.75,
#  'OGG': -5.777777777777778,
#  'OAK': -7.0,
#  'SMF': -9.0,
#  'KOA': -13.5,
#  'HNL': -6.285714285714286,
#  'SJC': -4.0,
#  'SEA': -2.6666666666666665,
#  'SAN': -4.0,
#  'LIH': -8.0,
#  'ANC': -9.0,
#  'DCA': -7.5}

# %% [markdown]
# For this question, I watched the "hint for Question 5 on TDM 10200 Project 11" video to construct my code. The video is linked here: https://the-examples-book.com/programming-languages/python/hints-for-TDM-10200-project-11.
#
# For part a, I used the same class code that I created in question 1. However, I added another function right below arrdelay called, "get_depdelay" because this question wanted me to do the same thing that I did for question 3 and 4 but using the departure delay and origin airport data.
#
# For part b, I used the same function that I created in question 4. But, I replaced some words such as "arr" became "dep" and then "dest/destination" became origin. I also added the same code for longlistofflights that I created in question 2 and placed it in between the Flight class and function definition. This was because previously, I was getting an error and I found that this was the code that actually imported the data I have to use to calculate the average departure delay.
#
# For part c, I tested the function with longlistofflights as the input and my output was the same as the one shown in the video, suggesting that it is correct.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
