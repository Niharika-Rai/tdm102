# %% [markdown]
# # Project 7 -- [Niharika] [Rai]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
import pandas as pd 
myyear = 1880
myDF = pd.read_csv(f'/anvil/projects/tdm/data/noaa/{myyear}.csv', header=None, names=["id","date","element_code","value","mflag","qflag","sflag","obstime"])
us_records = myDF[myDF['id'].str.startswith('US')]
us_records.shape[0]
# Out:
# 48428

# %%
import pandas as pd 
myyear = 1881
myDF = pd.read_csv(f'/anvil/projects/tdm/data/noaa/{myyear}.csv', header=None, names=["id","date","element_code","value","mflag","qflag","sflag","obstime"])
us_records = myDF[myDF['id'].str.startswith('US')]
us_records.shape[0]
# Out:
# 48196

# %%
import pandas as pd 
myyear = 1882
myDF = pd.read_csv(f'/anvil/projects/tdm/data/noaa/{myyear}.csv', header=None, names=["id","date","element_code","value","mflag","qflag","sflag","obstime"])
us_records = myDF[myDF['id'].str.startswith('US')]
us_records.shape[0]
# Out:
# 50664

# %%
import pandas as pd 
myyear = 1883
myDF = pd.read_csv(f'/anvil/projects/tdm/data/noaa/{myyear}.csv', header=None, names=["id","date","element_code","value","mflag","qflag","sflag","obstime"])
us_records = myDF[myDF['id'].str.startswith('US')]
us_records.shape[0]
# Out:
# 52363

# %%
def get_noaa_data (myyear: int) -> pd.DataFrame:
    """
    This function accepts a 4-digit year as input, and returns a data frame that contains the NOAA data for that year

    Args:
    myyear (int): This is a 4-digit year for which we will load a data frame to be returned.

    Returns:
    myDF (pd.DataFrame): This is the data frame that contains the NOAA data for that year
    """
    myfilepath = f'/anvil/projects/tdm/data/noaa/{myyear}.csv'
    mycolumnnames=["id","date","element_code","value","mflag","qflag","sflag","obstime"]
    myDF = pd.read_csv(myfilepath, names=mycolumnnames)
    myDF['date'] = pd.to_datetime(myDF['date'], format="%Y%m%d")
    return myDF

# %%
get_noaa_data(1880).shape[0]
# Out:
# 370779

# %%
newDF = get_noaa_data(1883)
newDF[newDF['id'].str.startswith('US')].shape[0]
# Out:
# 52363

# %%
mydict = {} 
mylist = list(range(1880, 1884))
for myyear in mylist:
    newDF = get_noaa_data(myyear)
    mydict.update({myyear: newDF[newDF['id'].str.startswith('US')].shape[0]})

# %%
mydict
# Out:
# {1880: 48428, 1881: 48196, 1882: 50664, 1883: 52363}

# %%
def get_dict_with_us_records (mylist: int) -> dict:
    mydict = {} 
    mylist = list(range(1880, 1884))
    for myyear in mylist:
        newDF = get_noaa_data(myyear)
        mydict.update({myyear: newDF[newDF['id'].str.startswith('US')].shape[0]})
    return mydict

# %%
get_dict_with_us_records (list(range(1880, 1884)))
# Out:
# {1880: 48428, 1881: 48196, 1882: 50664, 1883: 52363}

# %% [markdown]
# For question 1, parts a and b, I watched the first two videos here: https://the-examples-book.com/programming-languages/python/some-examples-for-TDM-10200-project-7. I also got the code sturucture of def get_noaa_data from the tip above question 1 in the examples textbook. I, then individually found the results for each of the years before looping them to create the dictionary and the function. However, one thing that I did differenty was directly use the .shape[0] attribute rather than just use .shape after us_records because I specifically had to get the number of rows as my output.

# %% [markdown]
# ## Question 2

# %%
mydict = {} 
mylist = list(range(1880, 1884))
for myyear in mylist:
    newDF = get_noaa_data(myyear)
    mydict.update({myyear: newDF[newDF['id'].str.startswith('US')].shape[0]})
mydescendingdict = dict([key, mydict[key]] for key in sorted(mydict, key=mydict.get, reverse=True))

# %%
mydescendingdict
# Out:
# {1883: 52363, 1882: 50664, 1880: 48428, 1881: 48196}

# %%
def get_mydescendingdict (mylist: int) -> dict:
    mydict = {} 
    mylist = list(range(1880, 1884))
    for myyear in mylist:
        newDF = get_noaa_data(myyear)
        mydict.update({myyear: newDF[newDF['id'].str.startswith('US')].shape[0]})
        mydescendingdict = dict([key, mydict[key]] for key in sorted(mydict, key=mydict.get, reverse=True))
    return mydescendingdict

# %%
get_mydescendingdict (list(range(1880, 1884)))
# Out:
# {1883: 52363, 1882: 50664, 1880: 48428, 1881: 48196}

# %% [markdown]
# For question 2, part a, I watched the third video under this link: https://the-examples-book.com/programming-languages/python/some-examples-for-TDM-10200-project-7. I also got the code sturucture of mydescending dict from the tip below question 2 in the examples textbook. Since, I already had the dictionary created from my work in question 1, I used that same dictionary but I used the mydescending dict code to get the final output. When I got the reversed order dictionary, I created my function using the same steps as in question 1 but adding an extra variable of mydescendingdict to get the output in reversed order.

# %% [markdown]
# ## Question 3

# %%
newDF = get_noaa_data(1880)
newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]
# Out:
# 203

# %%
newDF = get_noaa_data(1881)
newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]
# Out:
# 266

# %%
newDF = get_noaa_data(1882)
newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]
# Out:
# 253

# %%
newDF = get_noaa_data(1883)
newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]
# Out:
# 187

# %%
mydict = {} 
mylist = list(range(1880, 1884))
for myyear in mylist:
    newDF = get_noaa_data(myyear)
    mydict.update({myyear: newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]})

# %%
mydict
# Out:
# {1880: 203, 1881: 266, 1882: 253, 1883: 187}

# %%
def get_dict_with_specified_rows (mylist: int) -> dict:
    mydict = {}
    mylist = list(range(1880, 1884))
    for myyear in mylist:
        newDF = get_noaa_data(myyear)
        mydict.update({myyear: newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0]})
    return mydict

# %%
get_dict_with_specified_rows (list(range(1880, 1884)))
# Out:
# {1880: 203, 1881: 266, 1882: 253, 1883: 187}

# %% [markdown]
# For this question, I watched the fourth video under this link: https://the-examples-book.com/programming-languages/python/some-examples-for-TDM-10200-project-7. I also got the code sturucture for finding the rows specifically for US data with positive values from the video. Once my code worked, I created the dictionary and function using the same steps I used in question 1. However, I replaced my code after myyear: to the output I wanted which was: newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)].shape[0] to get the number of specified rows with US records, element_code == 'SNOW' and values being strictly positive because this is suppose to be my output for this question. After doing this, I created my function and it also gave me the same output as the dictionary.

# %% [markdown]
# ## Question 4

# %%
newDF = get_noaa_data(1880)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id').size().idxmax()
# Out:
# 'USW00024128'

# %%
newDF = get_noaa_data(1881)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id').size().idxmax()
# Out:
# 'USC00464045'

# %%
newDF = get_noaa_data(1882)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id').size().idxmax()
# Out:
# 'USC00176902'

# %%
newDF = get_noaa_data(1883)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id').size().idxmax()
# Out:
# 'USC00176902'

# %%
mydict = {} 
mylist = list(range(1880, 1884))
for myyear in mylist:
    newDF = get_noaa_data(myyear)
    snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
    mydict.update({myyear: snowyDF.groupby('id').size().idxmax()})

# %%
mydict
# Out:
# {1880: 'USW00024128',
#  1881: 'USC00464045',
#  1882: 'USC00176902',
#  1883: 'USC00176902'}

# %%
def get_id_with_largest_number_of_snowfall (mylist: int) -> dict:
    mydict = {}
    mylist = list(range(1880, 1884))
    for myyear in mylist:
        newDF = get_noaa_data(myyear)
        snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
        mydict.update({myyear: snowyDF.groupby('id').size().idxmax()})
    return mydict

# %%
get_id_with_largest_number_of_snowfall (list(range(1880, 1884)))
# Out:
# {1880: 'USW00024128',
#  1881: 'USC00464045',
#  1882: 'USC00176902',
#  1883: 'USC00176902'}

# %% [markdown]
# For this question, I watched the fifth video in this link: https://the-examples-book.com/programming-languages/python/some-examples-for-TDM-10200-project-7. The process of creating the dictionary and function was the same, from question 1, after I got the proper code structure to extract my output. Hence, in my dictionary, I replaced the code after myyear to: snowyDF.groupby('id').size().idxmax(). Before that, I created another variable called snowyDF which had the specifications of rows from question 3 (US records, element_code == 'SNOW' and values being positive). From these rows, I had to extract the 'id' with the largest number of snowfall days for each of these years. So, I grouped the data in terms of 'id', used the size() function to count the number of snowfall days, and finally used the idxmax() function to extract the ids with the maximum count. My function also gave me the same output as my dictionary which means that my work is correct.

# %% [markdown]
# ## Question 5

# %%
newDF = get_noaa_data(1880)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id')['value'].sum().idxmax()
# Out:
# 'USC00464045'

# %%
newDF = get_noaa_data(1881)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id')['value'].sum().idxmax()
# Out:
# 'USW00014971'

# %%
newDF = get_noaa_data(1882)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id')['value'].sum().idxmax()
# Out:
# 'USC00176902'

# %%
newDF = get_noaa_data(1883)
snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
snowyDF.groupby('id')['value'].sum().idxmax()
# Out:
# 'USC00464045'

# %%
mydict = {} 
mylist = list(range(1880, 1884))
for myyear in mylist:
    newDF = get_noaa_data(myyear)
    snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
    mydict.update({myyear: snowyDF.groupby('id')['value'].sum().idxmax()})

# %%
mydict
# Out:
# {1880: 'USC00464045',
#  1881: 'USW00014971',
#  1882: 'USC00176902',
#  1883: 'USC00464045'}

# %%
def get_id_with_largest_amount_of_snowfall (mylist: int) -> dict:
    mydict = {}
    mylist = list(range(1880, 1884))
    for myyear in mylist:
        newDF = get_noaa_data(myyear)
        snowyDF = newDF[(newDF['id'].str.startswith('US')) & (newDF['element_code'] == "SNOW") & (newDF['value'] > 0)] 
        mydict.update({myyear: snowyDF.groupby('id')['value'].sum().idxmax()})
    return mydict

# %%
get_id_with_largest_amount_of_snowfall (list(range(1880, 1884)))
# Out:
# {1880: 'USC00464045',
#  1881: 'USW00014971',
#  1882: 'USC00176902',
#  1883: 'USC00464045'}

# %% [markdown]
# For this question, I watched the sixth video in this link: https://the-examples-book.com/programming-languages/python/some-examples-for-TDM-10200-project-7. The process of creating the dictionary and function was the same, from question 1, after I got the proper code structure to extract my output. Hence, in my dictionary, I replaced the code after myyear to: snowyDF.groupby('id')['value'].sum().idxmax(). This snowyDF was the same one also used and created for question 4. From these rows, I had to extract the 'id' with the largest amount of snowfall for each of these years. So, I grouped the data in terms of 'id', used the ['value'].sum() function to find the amounts of snowfall, and finally used the idxmax() function to extract the ids with the maximum amount of snowfall. My function also gave me the same output as my dictionary which means that my work is correct.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
