# %% [markdown]
# # Project 2 -- [Niharika] [Rai]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
mydata = [ ("Niharika" , "Student" , 18 , "Business Analytics and Information Management" , "Purdue University" , "West Lafayette"), 
           ("Tanvi" , "Undergraduate", 19 , "Biochemistry" , "Purdue University", "Greenwood") ] 
mydata
# Out:
# [('Niharika',
#   'Student',
#   18,
#   'Business Analytics and Information Management',
#   'Purdue University',
#   'West Lafayette'),
#  ('Tanvi',
#   'Undergraduate',
#   19,
#   'Biochemistry',
#   'Purdue University',
#   'Greenwood')]

# %%
import pandas as pd
studentDF = pd.DataFrame(mydata)
studentDF
# Out:
#           0              1   2                                              3  \
# 0  Niharika        Student  18  Business Analytics and Information Management
# 1     Tanvi  Undergraduate  19                                   Biochemistry
#
#                    4               5
# 0  Purdue University  West Lafayette
# 1  Purdue University       Greenwood

# %%
print(studentDF.iloc[1, ])
# Out:
# 0                Tanvi
# 1        Undergraduate
# 2                   19
# 3         Biochemistry
# 4    Purdue University
# 5            Greenwood
# Name: 1, dtype: object

# %% [markdown]
# For part a, I watched this video: https://the-examples-book.com/programming-languages/python/pandas-dataframe-constructor and followed the same pattern. But the information presented in the 6 tuples is about me and my friend. For part b, I watched the continuation of the same video linked for part a. I also read the Data Frame Constructor page in the Examples Book: (https://the-examples-book.com/programming-languages/python/pandas-dataframes#dataframe-constructor) and followed the same code pattern. But I replaced some of the words with the details given to me by this question. For example, myDF became studentDF. For part c, I wanted the ending of the same video linked for part a. I also read the website given in the tip: https://www.w3schools.com/python/pandas/ref_df_iloc.asp and followed the code pattern on the last sentence. Since, I wanted all the information about the second person, I removed 0 from the brackets.

# %% [markdown]
# ## Question 2

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 

myDF.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 

myDF.tail()
# Out:
#                 id                                                url  \
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# 426875  wyoming  https://wyoming.craigslist.org  23590  2019.0       nissan
# 426876  wyoming  https://wyoming.craigslist.org  30590  2020.0        volvo
# 426877  wyoming  https://wyoming.craigslist.org  34990  2020.0     cadillac
# 426878  wyoming  https://wyoming.craigslist.org  28990  2018.0        lexus
# 426879  wyoming  https://wyoming.craigslist.org  30590  2019.0          bmw
#
#                            model condition    cylinders  ... size       type  \
# ...

# %% [markdown]
# For question 2, parts a and b, I followed the code structure based on the warning and tip given. However, in the tip, only .head() and .tail() was written. So, I modified this code into myDF.head() and myDF.tail() so that I can display the first and last 5 rows of my data set. I got this idea by reading this page in the Examples book: https://the-examples-book.com/programming-languages/python/pandas-read-write-data. I also watched this video and set my cores to 3: https://the-examples-book.com/starter-guides/anvil/starting-an-anvil-session. For this question, my kernel just dies and I am not able to run this code despite having followed all instructions.

# %% [markdown]
# ## Question 3

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 
print(myDF.shape)
# Out:
# (426880, 26)

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 
myDF.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %% [markdown]
# For question 3, part a, I followed the code structure under shape from this website: https://note.nkmk.me/en/python-pandas-len-shape-size/. I had also used this website for project 1, question 5. For part b, I watched this video: https://the-examples-book.com/programming-languages/python/pandas-shape. This video was linked under project 1, question 5. I specifically got the code structure for displaying the list for all column names from this video.

# %% [markdown]
# ## Question 4

# %%
myDF[myDF["price"] > 6000].shape
# Out:
# (312633, 26)

# %%
myDF["state"].unique()
# Out:
# array(['az', 'ar', 'fl', 'ma', 'nc', 'ny', 'or', 'pa', 'tx', 'wa', 'wi',
#        'al', 'ak', 'ca', 'co', 'ct', 'dc', 'de', 'ga', 'hi', 'id', 'il',
#        'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'mi', 'mn', 'ms', 'mo',
#        'mt', 'ne', 'nv', 'nj', 'nm', 'nh', 'nd', 'oh', 'ok', 'ri', 'sc',
#        'sd', 'tn', 'ut', 'vt', 'va', 'wv', 'wy'], dtype=object)

# %%
len(myDF["state"].unique())
# Out:
# 51

# %%
myDF[myDF["state"] == "in"].shape
# Out:
# (5704, 26)

# %%
myDF[myDF["state"] == "tx"].shape
# Out:
# (22945, 26)

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 
myDF["region"].unique()
# Out:
# array(['prescott', 'fayetteville', 'florida keys',
#        'worcester / central MA', 'greensboro', 'hudson valley',
#        'medford-ashland', 'erie', 'el paso', 'bellingham',
#        'skagit / island / SJI', 'la crosse', 'auburn', 'birmingham',
#        'dothan', 'florence / muscle shoals', 'gadsden-anniston',
#        'huntsville / decatur', 'mobile', 'montgomery', 'tuscaloosa',
#        'anchorage / mat-su', 'fairbanks', 'kenai peninsula',
#        'southeast alaska', 'flagstaff / sedona', 'mohave county',
#        'phoenix', 'show low', 'sierra vista', 'tucson', 'yuma',
#        'fort smith', 'jonesboro', 'little rock', 'texarkana',
#        'bakersfield', 'chico', 'fresno / madera', 'gold country',
#        'hanford-corcoran', 'humboldt county', 'imperial county',
#        'inland empire', 'los angeles', 'mendocino county', 'merced',
#        'modesto', 'monterey bay', 'orange county', 'palm springs',
#        'redding', 'reno / tahoe', 'sacramento', 'san diego',
# ...

# %%
len(myDF["region"].unique())
# Out:
# 404

# %% [markdown]
# For question 4, part a, b and c I got the code structure from this video: https://the-examples-book.com/programming-languages/python/pandas-breweries-examples#breweries-per-state. Although the data was different, the structure remained the same. Based on the reading of the data, I think that each row represents one unique vehicle. Hence, a total of 312633 vehicles have a price strictly above $6000. In part b, I had to abbreviate Indiana and Texas as "in" and "tx" because that was how they were listed in the column under state. To identify their abbreviation, I first had to identify all the states in this data. Hence, I used the unique() function. After that, my code pattern resembled based on what I learnt from the video linked above. To answer part b, 5704 vehicles are from Indiana and 22945 vehicles are from Texas. For part c, I followed the same code structure as I had for part b, but the only difference was that I replaced "state" with "region" and used the len() function to calculate how many times these regions occured when counting them only once. To answer part c, there a total of 404 regions displaced in this data set.

# %% [markdown]
# ## Question 5

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/craigslist/vehicles.csv") 

subDF = myDF[myDF["price"] < 6000] 
vehiclesDF = subDF.groupby("state").size() 
vehiclesDF
# Out:
# state
# ak      283
# al      982
# ar     1264
# az     1754
# ca    13650
# co     2404
# ct     1505
# dc      942
# de      296
# fl     7299
# ga     1866
# hi      729
# ia     1881
# id     2050
# il     3011
# in     1268
# ks     1358
# ky      659
# la      868
# ma     2369
# md     1448
# me     1036
# mi     4746
# mn     2023
# mo      866
# ms      252
# mt      991
# nc     4831
# nd       59
# ne      186
# nh      783
# nj     2850
# nm     1144
# nv      545
# ny     5071
# oh     5649
# ok     2073
# or     6460
# pa     3916
# ri      599
# sc     1474
# sd      315
# tn     1980
# tx     5463
# ut      180
# va     3944
# vt      494
# wa     3737
# wi     2871
# wv      145
# wy      101
# dtype: int64

# %%
earlyratingsDF.plot(kind = "bar", figsize = (20,9)) 
import matplotlib.pyplot as plt
plt.title("Number of Vehicles Per State")
plt.xlabel("State") 
plt.ylabel("Number of Vehicles") 
plt.show()

# %% [markdown]
# For question 5, I followed the part 1 and 2 videos under tip: https://the-examples-book.com/programming-languages/python/pandas-breweries-examples#part-1-video and https://the-examples-book.com/programming-languages/python/pandas-breweries-examples#part-2-video. These two videos helped me construct my code. However, I changed the words such as "ratings" to "vehicles" and "users" to "state" so that the bar chart is more relevant to the question. I used the subDF variable to isolate the number of vehicles and states from the entire dataset as that is what I needed to construct the bar chart. Instead of earlyratingsDF in the video, I assigned the subDF to a new variable called, vehiclesDF so that it is more relevant to the question. I did not want to rotate my graph by 45 degrees so I did not include that code. I capitalized the title and subtitles so that the figure looks more neat.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
