# %% [markdown]
# # Project 01 -- [Niharika] [Rai]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
N/A

# %% [markdown]
# For question 1, I copied the template in my home directory and saved it. I also filled out the information. I do not know what to code here. Nothing is mentioned in the examples book for question 1 except for the initial instructions. Hence, for the code, I just wrote N/A.

# %% [markdown]
# ## Question 2

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# I followed the instruction and typed the information above using the Tip given in question 2.

# %% [markdown]
# ## Question 3

# %%
num1 = int(input("Enter an integer")) 
num2 = int(input("Enter a second integer")) 
num1+num2== ["result here"] 
print("The sum of the two numbers is: [result here]")
# Out:
# Enter an integer 2
# Enter a second integer 4
# The sum of the two numbers is: [result here]

# %% [markdown]
# For the 1st and 2nd lines of the code, I followed the same pattern shown in the instructions for question 3. But for the code in line 2, I added an additional word, "second" because each of the integers must be different values. This is what I understood by reading the question. For the code in line 3, I read the "logical operators" page in "The Examples Book" and equated the value to "result here". This is because the string showed in the instructions just showed, "result here" and did not ask to input a specific value. Hence, I ran the code to check and for the result, it did not calculate the final answer but instead showed the phrase, "result here".

# %% [markdown]
# ## Question 4

# %%
myfruits = []
for i in range(1,6):
    myfruits.append(input(f"Name of the Fruit {i}: ")) 
print(myfruits)
# Out:
# Name of the Fruit 1:  Melon
# Name of the Fruit 2:  Watermelon
# Name of the Fruit 3:  Orange
# Name of the Fruit 4:  Apple
# Name of the Fruit 5:  Mango
# ['Melon', 'Watermelon', 'Orange', 'Apple', 'Mango']

# %% [markdown]
# I followed the pattern of the 2nd code in the website given: https://stackoverflow.com/questions/74969278/write-a-program-to-store-seven-fruits-in-a-list-entered-by-the-user. But since I had to declare a list called myfruits, I replaced fruits with myfruits. For the second line in this code, I read the note given about range and followed the instructions given for question 4.

# %% [markdown]
# ## Question 5

# %%
import pandas as pd
forest = pd.read_csv("/anvil/projects/tdm/data/forest/ENTIRE_COUNTY.csv")
forest.info() 
print(forest.shape) 
print(len(forest)) 
print(len(forest.columns)) 
print(forest.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3250 entries, 0 to 3249
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   STATECD               3250 non-null   int64
#  1   UNITCD                3250 non-null   int64
#  2   COUNTYCD              3250 non-null   int64
#  3   COUNTYNM              3250 non-null   object
#  4   CN                    3250 non-null   int64
#  5   CREATED_BY            3250 non-null   object
#  6   CREATED_DATE          3250 non-null   object
#  7   CREATED_IN_INSTANCE   3250 non-null   int64
#  8   MODIFIED_BY           1355 non-null   object
#  9   MODIFIED_DATE         1355 non-null   object
#  10  MODIFIED_IN_INSTANCE  1355 non-null   float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 279.4+ KB
# (3250, 11)
# 3250
# 11
# 35750

# %% [markdown]
# For this question, I read the website linked under question 5: https://note.nkmk.me/en/python-pandas-len-shape-size/
# In this link, I understood how to display the information using info, shape, size, len and columns. The examples on this website used the variable "df". But since, I declared my variable as forest, I replaced the "df" with "forest" when constructing my code. Only the info function is displaying all of the information at once such as the number of rowas, columns, non-null count and the data type. The other functions worked to get specific values such as the number or rows, the number of columns, and so on. Hence, I tried all these functions to verify the codes.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
